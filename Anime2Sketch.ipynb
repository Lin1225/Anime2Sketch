# %% [markdown]
# <a href="https://colab.research.google.com/github/Lin1225/Anime2Sketch/blob/master/Anime2Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anime2Sketch Colab implement

# %% [markdown]
# ## **Get Repo**
#
#
# ##### Original Repo https://github.com/Mukosame/Anime2Sketch

# %%
# !git clone https://github.com/Lin1225/Anime2Sketch.git

# %% [markdown]
# ## **Install dependencies**

# %%
# %cd Anime2Sketch/
# !pip3 install -r requirements.txt
# !mkdir results

# %% [markdown]
# ## **get model to your weights/ folder**
# * https://drive.google.com/file/d/122F00v5ZDkLFtB_vvXjeE2HC0pmQxWj7/view?usp=sharing.
# * https://drive.google.com/drive/folders/1Srf-WYUixK0wiUddc9y3pNKHHno5PN6R

# %%
# !pip3 install gshell
# !gdown https://drive.google.com/uc?id=122F00v5ZDkLFtB_vvXjeE2HC0pmQxWj7
# !mv netG.pth weights/

# %% [markdown]
# ## **Get image to test_samples**
# #### *this pic is in test_samples/ folder*
# ![aa.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **RUN**

# %%
# !python3 test.py --dataroot test_samples/aa.jpg --load_size 1024 --output_dir results/

# %% [markdown]
# ## **The ouput will be in the results/ folder, nameed aa.jpg**
# ![final.jpg](data:image/jpeg;base64,...)
